# %%
import numpy as np
import pandas as pd
import seaborn as sb
import os

# %%
dataframe = pd.read_csv('Before.csv')
dataframe.head()
# Out:
#   Fitur Kontras    Derajat 0   Derajat 45   Derajat 90  Derajat 135  \
# 0        0_left   994.068897  1220.513526   723.052118  1220.354787
# 1      103_left  1172.177532  1409.981992   833.404275  1425.490581
# 2    1062_right  1839.014625  2089.586067  1332.257870  2020.694041
# 3     1083_left  1732.903622  2116.256101  1428.772088  2092.117878
# 4    1084_right  2020.819931  2244.640200  1150.727336  2207.320123
#
#   Fitur Dissimilarity  Derajat 0.1  Derajat 45.1  Derajat 90.1  Derajat 135.1  \
# 0              0_left     4.083998      4.953387      3.023329       4.951942
# 1            103_left     4.819008      5.730396      3.493841       5.789296
# 2          1062_right     7.534948      8.486336      5.555125       8.214810
# 3           1083_left     7.187420      8.644321      6.002384       8.553433
# 4          1084_right     8.280938      9.119277      4.873218       8.971826
#
#    ... Fitur Energy  Derajat 0.5  Derajat 45.5  Derajat 90.5  Derajat 135.5  \
# ...

# %%
dataframe.columns
# Out:
# Index(['Fitur Kontras', 'Derajat 0', 'Derajat 45', 'Derajat 90', 'Derajat 135',
#        'Fitur Dissimilarity', 'Derajat 0.1', 'Derajat 45.1', 'Derajat 90.1',
#        'Derajat 135.1', 'Fitur Homogenitas', 'Derajat 0.2', 'Derajat 45.2',
#        'Derajat 90.2', 'Derajat 135.2', 'Fitur Entropi', 'Derajat 0.3',
#        'Derajat 45.3', 'Derajat 90.3', 'Derajat 135.3', 'Fitur ASM',
#        'Derajat 0.4', 'Derajat 45.4', 'Derajat 90.4', 'Derajat 135.4',
#        'Fitur Energy', 'Derajat 0.5', 'Derajat 45.5', 'Derajat 90.5',
#        'Derajat 135.5', 'Fitur Correlations', 'Derajat 0.6', 'Derajat 45.6',
#        'Derajat 90.6', 'Derajat 135.6'],
#       dtype='object')

# %%
clean_data  = dataframe.drop(columns=['Fitur Kontras', 'Fitur Dissimilarity','Fitur Entropi', 'Fitur Homogenitas', 'Fitur Entropi', 'Fitur ASM', 'Fitur Correlations', 'Fitur Energy'])
clean_data = clean_data.replace({
    'Cataract': 0,
    'Myopia': 1,
    'Normal': 2
})
clean_data.head()
# Out:
#      Derajat 0   Derajat 45   Derajat 90  Derajat 135  Derajat 0.1  \
# 0   994.068897  1220.513526   723.052118  1220.354787     4.083998
# 1  1172.177532  1409.981992   833.404275  1425.490581     4.819008
# 2  1839.014625  2089.586067  1332.257870  2020.694041     7.534948
# 3  1732.903622  2116.256101  1428.772088  2092.117878     7.187420
# 4  2020.819931  2244.640200  1150.727336  2207.320123     8.280938
#
#    Derajat 45.1  Derajat 90.1  Derajat 135.1  Derajat 0.2  Derajat 45.2  ...  \
# 0      4.953387      3.023329       4.951942     0.938290      0.940618  ...
# 1      5.730396      3.493841       5.789296     0.925870      0.928596  ...
# 2      8.486336      5.555125       8.214810     0.893476      0.897975  ...
# 3      8.644321      6.002384       8.553433     0.874269      0.880804  ...
# 4      9.119277      4.873218       8.971826     0.882523      0.888469  ...
#
#    Derajat 90.4  Derajat 135.4  Derajat 0.5  Derajat 45.5  Derajat 90.5  \
# ...

# %%
clean_data.columns
# Out:
# Index(['Derajat 0', 'Derajat 45', 'Derajat 90', 'Derajat 135', 'Derajat 0.1',
#        'Derajat 45.1', 'Derajat 90.1', 'Derajat 135.1', 'Derajat 0.2',
#        'Derajat 45.2', 'Derajat 90.2', 'Derajat 135.2', 'Derajat 0.3',
#        'Derajat 45.3', 'Derajat 90.3', 'Derajat 135.3', 'Derajat 0.4',
#        'Derajat 45.4', 'Derajat 90.4', 'Derajat 135.4', 'Derajat 0.5',
#        'Derajat 45.5', 'Derajat 90.5', 'Derajat 135.5', 'Derajat 0.6',
#        'Derajat 45.6', 'Derajat 90.6', 'Derajat 135.6'],
#       dtype='object')

# %%
len(clean_data.columns)
# Out:
# 28

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


x = clean_data.iloc[:,:-1]
y = clean_data.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

scaler = MinMaxScaler()
x_train_scalled = scaler.fit_transform(x_train)
x_test_scalled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

regressor = LinearRegression()

regressor.fit(x_train_scalled, y_train)

y_pred_continuous = regressor.predict(x_test_scalled)

mse = mean_squared_error(y_test, y_pred_continuous)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 1.868415807358012e-05

# %% [markdown]
# 1.8 * 10^-5
