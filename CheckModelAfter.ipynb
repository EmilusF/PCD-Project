# %%
import numpy as np
import pandas as pd
import seaborn as sb
import os

# %%
dataframe = pd.read_csv('After.csv')
dataframe.head()
# Out:
#   Fitur Kontras   Derajat 0  Derajat 45  Derajat 90  Derajat 135  \
# 0        0_left  222.558739  293.029481  177.060669   273.381407
# 1      103_left  200.390065  253.248074  131.412718   236.548035
# 2    1062_right  253.109727  358.309235  238.397447   364.584913
# 3     1083_left   56.925829   70.728920   62.087812    97.504990
# 4    1084_right  187.476448  220.486090  120.311819   218.920754
#
#   Fitur Dissimilarity  Derajat 0.1  Derajat 45.1  Derajat 90.1  Derajat 135.1  \
# 0              0_left     2.620777      3.031972      2.291949       2.940715
# 1            103_left     2.127920      2.446167      1.635402       2.372349
# 2          1062_right     2.924352      3.513818      2.898731       3.539346
# 3           1083_left     1.523568      1.727582      1.238785       1.848612
# 4          1084_right     3.263606      3.588035      2.809443       3.591665
#
#    ... Fitur Energy  Derajat 0.5  Derajat 45.5  Derajat 90.5  Derajat 135.5  \
# 0  ...       0_left     0.421690      0.420491      0.422523       0.420538
# 1  ...     103_left     0.563455      0.562587      0.564546       0.562545
# 2  ...   1062_right     0.307526      0.306121      0.307651       0.305985
# 3  ...    1083_left     0.564092      0.563159      0.564979       0.563001
# 4  ...   1084_right     0.331485      0.330836      0.333141       0.330796
#
#   Fitur Correlations  Derajat 0.6  Derajat 45.6  Derajat 90.6  Derajat 135.6
# 0             0_left     0.982799      0.977352      0.986315       0.978871
# 1           103_left     0.986961      0.983522      0.991449       0.984609
# 2         1062_right     0.986554      0.980965      0.987335       0.980632
# 3          1083_left     0.992471      0.990645      0.991788       0.987104
# 4         1084_right     0.979709      0.976137      0.986979       0.976307
#
# [5 rows x 35 columns]

# %%
dataframe.columns
# Out:
# Index(['Fitur Kontras', 'Derajat 0', 'Derajat 45', 'Derajat 90', 'Derajat 135',
#        'Fitur Dissimilarity', 'Derajat 0.1', 'Derajat 45.1', 'Derajat 90.1',
#        'Derajat 135.1', 'Fitur Homogenitas', 'Derajat 0.2', 'Derajat 45.2',
#        'Derajat 90.2', 'Derajat 135.2', 'Fitur Entropi', 'Derajat 0.3',
#        'Derajat 45.3', 'Derajat 90.3', 'Derajat 135.3', 'Fitur ASM',
#        'Derajat 0.4', 'Derajat 45.4', 'Derajat 90.4', 'Derajat 135.4',
#        'Fitur Energy', 'Derajat 0.5', 'Derajat 45.5', 'Derajat 90.5',
#        'Derajat 135.5', 'Fitur Correlations', 'Derajat 0.6', 'Derajat 45.6',
#        'Derajat 90.6', 'Derajat 135.6'],
#       dtype='object')

# %%
clean_data  = dataframe.drop(columns=['Fitur Kontras', 'Fitur Dissimilarity','Fitur Entropi', 'Fitur Homogenitas', 'Fitur Entropi', 'Fitur ASM', 'Fitur Correlations', 'Fitur Energy'])
clean_data = clean_data.replace({
    'Cataract': 0,
    'Myopia': 1,
    'Normal': 2
})
clean_data.head()
# Out:
#     Derajat 0  Derajat 45  Derajat 90  Derajat 135  Derajat 0.1  Derajat 45.1  \
# 0  222.558739  293.029481  177.060669   273.381407     2.620777      3.031972
# 1  200.390065  253.248074  131.412718   236.548035     2.127920      2.446167
# 2  253.109727  358.309235  238.397447   364.584913     2.924352      3.513818
# 3   56.925829   70.728920   62.087812    97.504990     1.523568      1.727582
# 4  187.476448  220.486090  120.311819   218.920754     3.263606      3.588035
#
#    Derajat 90.1  Derajat 135.1  Derajat 0.2  Derajat 45.2  ...  Derajat 90.4  \
# 0      2.291949       2.940715     0.682549      0.676472  ...      0.178526
# 1      1.635402       2.372349     0.760906      0.754776  ...      0.318712
# 2      2.898731       3.539346     0.611187      0.605760  ...      0.094649
# 3      1.238785       1.848612     0.756728      0.746117  ...      0.319201
# 4      2.809443       3.591665     0.575485      0.570749  ...      0.110983
#
#    Derajat 135.4  Derajat 0.5  Derajat 45.5  Derajat 90.5  Derajat 135.5  \
# 0       0.176852     0.421690      0.420491      0.422523       0.420538
# 1       0.316457     0.563455      0.562587      0.564546       0.562545
# 2       0.093627     0.307526      0.306121      0.307651       0.305985
# 3       0.316970     0.564092      0.563159      0.564979       0.563001
# 4       0.109426     0.331485      0.330836      0.333141       0.330796
#
#    Derajat 0.6  Derajat 45.6  Derajat 90.6  Derajat 135.6
# 0     0.982799      0.977352      0.986315       0.978871
# 1     0.986961      0.983522      0.991449       0.984609
# 2     0.986554      0.980965      0.987335       0.980632
# 3     0.992471      0.990645      0.991788       0.987104
# 4     0.979709      0.976137      0.986979       0.976307
#
# [5 rows x 28 columns]

# %%
clean_data.columns
# Out:
# Index(['Derajat 0', 'Derajat 45', 'Derajat 90', 'Derajat 135', 'Derajat 0.1',
#        'Derajat 45.1', 'Derajat 90.1', 'Derajat 135.1', 'Derajat 0.2',
#        'Derajat 45.2', 'Derajat 90.2', 'Derajat 135.2', 'Derajat 0.3',
#        'Derajat 45.3', 'Derajat 90.3', 'Derajat 135.3', 'Derajat 0.4',
#        'Derajat 45.4', 'Derajat 90.4', 'Derajat 135.4', 'Derajat 0.5',
#        'Derajat 45.5', 'Derajat 90.5', 'Derajat 135.5', 'Derajat 0.6',
#        'Derajat 45.6', 'Derajat 90.6', 'Derajat 135.6'],
#       dtype='object')

# %%
len(clean_data.columns)
# Out:
# 28

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


x = clean_data.iloc[:,:-1]
y = clean_data.iloc[:,-1:]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

scaler = MinMaxScaler()
x_train_scalled = scaler.fit_transform(x_train)
x_test_scalled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

regressor = LinearRegression()

regressor.fit(x_train_scalled, y_train)

y_pred_continuous = regressor.predict(x_test_scalled)

mse = mean_squared_error(y_test, y_pred_continuous)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 1.7559851475672973e-07

# %% [markdown]
# 1.7 * 10^-7
